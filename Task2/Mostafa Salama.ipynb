# %% [markdown]
# # 1.Load and Inspect the Data

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\pc\OneDrive\Desktop\Cellule\First_task\first inten project.csv")
df=data.copy()
df
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
# ...

# %%
df.shape
# Out:
# (36285, 17)

# %%
df.isna().sum()
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %% [markdown]
# # 2. Data Cleaning

# %%
df = df.drop(columns=['Booking_ID'])
df
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# ...

# %%
df.duplicated().sum()
# Out:
# 10276

# %%
df['date of reservation'] = pd.to_datetime(df['date of reservation'], format='%m/%d/%Y', errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number of adults          36285 non-null  int64
#  1   number of children        36285 non-null  int64
#  2   number of weekend nights  36285 non-null  int64
#  3   number of week nights     36285 non-null  int64
#  4   type of meal              36285 non-null  object
#  5   car parking space         36285 non-null  int64
#  6   room type                 36285 non-null  object
#  7   lead time                 36285 non-null  int64
#  8   market segment type       36285 non-null  object
#  9   repeated                  36285 non-null  int64
#  10  P-C                       36285 non-null  int64
#  11  P-not-C                   36285 non-null  int64
#  12  average price             36285 non-null  float64
#  13  special requests          36285 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# number of adults             0
# number of children           0
# number of weekend nights     0
# number of week nights        0
# type of meal                 0
# car parking space            0
# room type                    0
# lead time                    0
# market segment type          0
# repeated                     0
# P-C                          0
# P-not-C                      0
# average price                0
# special requests             0
# date of reservation         37
# booking status               0
# dtype: int64

# %%
df[df.isna().any(axis=1)].index.tolist()
# Out:
# [2626,
#  3677,
#  5600,
#  6343,
#  7648,
#  8000,
#  8989,
#  9153,
#  9245,
#  9664,
#  9934,
#  10593,
#  10652,
#  10747,
#  11881,
#  13958,
#  14304,
#  15363,
#  15438,
#  17202,
#  18380,
#  18534,
#  18680,
#  19013,
#  20419,
#  21674,
#  21688,
#  26108,
#  27559,
#  27928,
#  30552,
#  30616,
#  30632,
#  30839,
#  32041,
#  34638,
#  35481]

# %%
df = df.dropna()
df.shape
# Out:
# (36248, 16)

# %%
df.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price   \
# ...

# %%
df.duplicated().sum()
# Out:
# 10274

# %%
df[df.duplicated()]
# Out:
#        number of adults  number of children  number of weekend nights  \
# 20                    2                   0                         2
# 154                   2                   0                         0
# 272                   2                   0                         1
# 301                   1                   0                         0
# 319                   2                   0                         0
# ...                 ...                 ...                       ...
# 36277                 1                   0                         2
# 36278                 2                   0                         0
# 36280                 2                   0                         0
# 36282                 2                   0                         1
# 36284                 2                   0                         0
#
#        number of week nights type of meal  car parking space    room type  \
# ...

# %%
row_to_check = df.iloc[319]  
df[df.eq(row_to_check).all(axis=1)]
# Out:
#       number of adults  number of children  number of weekend nights  \
# 96                   2                   0                         0
# 319                  2                   0                         0
# 724                  2                   0                         0
# 1637                 2                   0                         0
# 2032                 2                   0                         0
# 3736                 2                   0                         0
# 4646                 2                   0                         0
# 4701                 2                   0                         0
# 6452                 2                   0                         0
# 6814                 2                   0                         0
# 7072                 2                   0                         0
#
#       number of week nights type of meal  car parking space    room type  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36273                 2                   0                         0
# 36276                 2                   0                         2
# 36279                 2                   0                         1
# 36281                 2                   0                         1
# 36283                 3                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Understanding

# %%
df
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36273                 2                   0                         0
# 36276                 2                   0                         2
# 36279                 2                   0                         1
# 36281                 2                   0                         1
# 36283                 3                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# ...

# %% [markdown]
# -------------------------------------------------------------------------------------------------------
# number of adults – The number of adults included in the booking.
#
# number of children – The number of children included in the booking.
#
# number of weekend nights – The number of weekend nights (Friday and Saturday) the guests will stay.
#
# number of week nights – The number of weekday nights (Sunday to Thursday) the guests will stay.
#
# type of meal – The type of meal plan chosen for the booking (e.g., "Meal Plan 1", "Not Selected", etc.).
#
# car parking space – Indicates whether a parking space was reserved (1 for Yes, 0 for No).
#
# room type – The type of room assigned for the booking (e.g., "Room_Type 1").
#
# lead time – The number of days between the booking date and the arrival date.
#
# market segment type – The segment from which the booking was made (e.g., "Online", "Offline", etc.).
#
# repeated – Indicates whether the booking is from a repeated guest (1 for Yes, 0 for No).
#
# P-not-c : number of previous booking not canceled
#
# P-C : number of previous cancelation
#
# average price – The average price per night for the booking.
#
# special requests – The number of special requests made by the guest (e.g., additional amenities).
#
# date of reservation – The date on which the booking was made.
#
# booking status – The final status of the booking (either "Canceled" or "Not_Canceled").
#
# -------------------------------------------------------------------------------------------------------

# %%
df.describe()
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      25974.000000        25974.000000              25974.000000
# mean           1.890275            0.141295                  0.882113
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
# std            0.528671            0.462486                  0.887787
#
#        number of week nights  car parking space     lead time      repeated  \
# count           25974.000000       25974.000000  25974.000000  25974.000000
# mean                2.262108           0.042042     66.507585      0.032648
# min                 0.000000           0.000000      0.000000      0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['lead time'], color='skyblue')

plt.title('Boxplot of Lead Time', fontsize=14)
plt.xlabel('Lead Time', fontsize=12)

plt.show()

# %%
Q1 = df['lead time'].quantile(0.25)  
Q3 = df['lead time'].quantile(0.75)  
IQR = Q3 - Q1  
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['lead time'] < lower_bound) | (df['lead time'] > upper_bound)]
print("Number of outliers:", len(outliers))
# Out:
# Number of outliers: 815

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['lead time'], bins=30, kde=True, color='blue') 

plt.title('Distribution of Lead Time', fontsize=14)
plt.xlabel('Lead Time', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %%
Q1 = df['lead time'].quantile(0.25)  
Q3 = df['lead time'].quantile(0.75)  #
IQR = Q3 - Q1  
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df['lead time'] = df['lead time'].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['lead time'], color='skyblue')

plt.title('Boxplot of Lead Time', fontsize=14)
plt.xlabel('Lead Time', fontsize=12)

plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['lead time'], bins=30, kde=True, color='blue') 

plt.title('Distribution of Lead Time', fontsize=14)
plt.xlabel('Lead Time', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %%
features = ['booking status', 'type of meal', 'market segment type', 'room type']

plt.figure(figsize=(15, 10))

for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)  
    ax = sns.countplot(x=df[feature])

    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='bottom', fontsize=12, fontweight='bold')

    plt.title(f'Distribution of {feature}', fontsize=14)

plt.show()

# %%
df['repeated'].value_counts()
# Out:
# repeated
# 0    25126
# 1      848
# Name: count, dtype: int64

# %%
df['P-C'].value_counts()
# Out:
# P-C
# 0     25706
# 1       131
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        1
# 6         1
# Name: count, dtype: int64

# %%
df['P-not-C'].value_counts()
# Out:
# P-not-C
# 0     25177
# 1       219
# 2       112
# 3        78
# 4        64
# 5        60
# 6        35
# 7        24
# 8        23
# 9        19
# 10       18
# 11       14
# 12       12
# 14        9
# 15        8
# 16        7
# 13        7
# 18        6
# 20        6
# 21        6
# 17        6
# 19        6
# 22        6
# 25        3
# 27        3
# 24        3
# 23        3
# 44        2
# 29        2
# 48        2
# 28        2
# 30        2
# 32        2
# 31        2
# 26        2
# 46        1
# 55        1
# 45        1
# 57        1
# 53        1
# 54        1
# 58        1
# 41        1
# 40        1
# 43        1
# 35        1
# 50        1
# 56        1
# 33        1
# 37        1
# 42        1
# 51        1
# 38        1
# 34        1
# 39        1
# 52        1
# 49        1
# 47        1
# 36        1
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.strip()
x_feature = 'number of adults'
y_feature = 'average price'

plt.figure(figsize=(10, 6))
sns.lineplot(x=df[x_feature], y=df[y_feature], color='blue', marker='o')

plt.xlabel(x_feature, fontsize=12)
plt.ylabel(y_feature, fontsize=12)
plt.title(f'Line Plot of {x_feature} vs {y_feature}', fontsize=14)

plt.show()

# %%
df['Month'] = df['date of reservation'].dt.month

bookings_per_month = df.groupby('Month').size()

plt.figure(figsize=(10, 6))
plt.plot(bookings_per_month.index, bookings_per_month.values, marker='o', linestyle='-', color='b')

plt.xlabel("Month")
plt.ylabel("Number of Bookings")
plt.title("Bookings Per Month")
plt.xticks(range(1, 13))  # Ensure all months are labeled

plt.show()

# %% [markdown]
# # prepare the data for the model

# %%
df
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36273                 2                   0                         0
# 36276                 2                   0                         2
# 36279                 2                   0                         1
# 36281                 2                   0                         1
# 36283                 3                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# ...

# %%
df = df.drop(columns=['Month'])
df
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36273                 2                   0                         0
# 36276                 2                   0                         2
# 36279                 2                   0                         1
# 36281                 2                   0                         1
# 36283                 3                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder

# %%
df = pd.get_dummies(df, columns=['type of meal', 'market segment type'], drop_first=True)

df['booking status'] = df['booking status'].map({'Canceled': 0, 'Not_Canceled': 1})

room_order = ['Room_Type 1', 'Room_Type 2', 'Room_Type 3', 'Room_Type 4', 
              'Room_Type 5', 'Room_Type 6', 'Room_Type 7']
ordinal_encoder = OrdinalEncoder(categories=[room_order])
df['room type'] = ordinal_encoder.fit_transform(df[['room type']])

df.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  car parking space  room type  lead time  repeated  \
# 0                      5                  0        0.0      224.0         0
# 1                      3                  0        0.0        5.0         0
# 2                      3                  0        0.0        1.0         0
# 3                      2                  0        0.0      211.0         0
# 4                      2                  0        0.0       48.0         0
#
#    P-C  P-not-C  ...  special requests  date of reservation booking status  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

numerical_cols = ['number of adults', 'number of children', 'number of weekend nights', 
                  'number of week nights', 'lead time', 'average price', 'special requests']

scaler = MinMaxScaler()

df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

df.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0              0.25                 0.1                  0.285714
# 1              0.25                 0.0                  0.142857
# 2              0.50                 0.1                  0.142857
# 3              0.25                 0.0                  0.000000
# 4              0.25                 0.0                  0.142857
#
#    number of week nights  car parking space  room type  lead time  repeated  \
# 0               0.294118                  0        0.0   0.965517         0
# 1               0.176471                  0        0.0   0.021552         0
# 2               0.176471                  0        0.0   0.004310         0
# 3               0.117647                  0        0.0   0.909483         0
# 4               0.117647                  0        0.0   0.206897         0
#
#    P-C  P-not-C  ...  special requests  date of reservation booking status  \
# ...

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Correlation Heatmap of Features", fontsize=14)

plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('booking status',axis=1)
x
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                  0.25                 0.1                  0.285714
# 1                  0.25                 0.0                  0.142857
# 2                  0.50                 0.1                  0.142857
# 3                  0.25                 0.0                  0.000000
# 4                  0.25                 0.0                  0.142857
# ...                 ...                 ...                       ...
# 36273              0.50                 0.0                  0.000000
# 36276              0.50                 0.0                  0.285714
# 36279              0.50                 0.0                  0.142857
# 36281              0.50                 0.0                  0.142857
# 36283              0.75                 0.0                  0.000000
#
#        number of week nights  car parking space  room type  lead time  \
# ...

# %%
y=df['booking status'].copy()
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 36273    0
# 36276    1
# 36279    0
# 36281    1
# 36283    1
# Name: booking status, Length: 25974, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=44,shuffle=True)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (18181, 20) (7793, 20) (18181,) (7793,)

# %% [markdown]
# # Model

# %% [markdown]
# ## Logistic Reg

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
datetime_cols = x_train.select_dtypes(include=['datetime64']).columns.tolist()
print("Datetime Columns:", datetime_cols)

for col in datetime_cols:
    x_train[col + "_year"] = x_train[col].dt.year
    x_train[col + "_month"] = x_train[col].dt.month
    x_train[col + "_day"] = x_train[col].dt.day
    x_train = x_train.drop(columns=[col])  

# Repeat the same for x_test
for col in datetime_cols:
    x_test[col + "_year"] = x_test[col].dt.year
    x_test[col + "_month"] = x_test[col].dt.month
    x_test[col + "_day"] = x_test[col].dt.day
    x_test = x_test.drop(columns=[col])
# Out:
# Datetime Columns: ['date of reservation']

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_reg.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")
# Out:
# Model Accuracy: 0.7872

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)


k = 5  
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(x_train_scaled, y_train)


y_pred = knn.predict(x_test_scaled)


accuracy = accuracy_score(y_test, y_pred)
print(f"KNN Model Accuracy: {accuracy:.4f}")
# Out:
# KNN Model Accuracy: 0.8112

# %% [markdown]
# ## XGboost

# %%
from xgboost import XGBClassifier

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
xgb_model = XGBClassifier(
    n_estimators=100,  
    learning_rate=0.1,  
    max_depth=6,  
    subsample=0.8,  
    colsample_bytree=0.8,  
    random_state=42
)

# %%
xgb_model.fit(x_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = xgb_model.predict(x_test_scaled)


accuracy = accuracy_score(y_test, y_pred)
print(f"XGBoost Model Accuracy: {accuracy:.4f}")
# Out:
# XGBoost Model Accuracy: 0.8606

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,  
    max_depth=None,  
    min_samples_split=2, 
    min_samples_leaf=1,  
    bootstrap=True,  
    random_state=42
)

# %%
rf_model.fit(x_train_scaled, y_train)
y_pred = rf_model.predict(x_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Random Forest Model Accuracy: {accuracy:.4f}")
# Out:
# Random Forest Model Accuracy: 0.8544
